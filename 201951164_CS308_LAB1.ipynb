# %% [markdown]
# #                                                     <center> **ML Assignment 1**</center>
#
# #                                                      <center> **Urmila Rathore**</center>
#
# #                                                       <center>**201951164**</center>

# %% [markdown]
# ## <font color='green'>1. Evaluate the expression $a^3+\sqrt{bd}-4c$, where
#
#
# $a=1.2, b=2.3, c=4.5$ and $d=4$.</font>

# %%
a,b,c,d=1.2,2.3,4.5,4
print(pow(a,3)+pow(b*d,0.5)-4*c)
# Out:
# -13.23884982237938

# %% [markdown]
# # <font color='green'>2. Consider the two matrices: </font>
#
# $A=\begin{bmatrix}4 & -6 \\6 & 10
# \end{bmatrix}$ $B=\begin{bmatrix}6 & -13 \\3.4 & 16
# \end{bmatrix}$.
# ## <font color='[link text](https://)'>Find: (a) $A+B$ (b) $B^2$ (c) $AB$ (d) $B^TA^T$ (e) Replace the second column of $A$ with that of $B$.

# %%
import numpy as np

A=np.array([[4.0,-6.0],[6.0,10.0]])
B=np.array([[6.0,-13.0],[3.4,16.0]])

print(np.add(A,B))

print(B@B)

print(A@B)

print(B.transpose()@B.transpose())

A[-1:]=B[-1:]
print(A)
# Out:
# [[ 10.  -19. ]
#  [  9.4  26. ]]
# [[  -8.2 -286. ]
#  [  74.8  211.8]]
# [[   3.6 -148. ]
#  [  70.    82. ]]
# [[  -8.2   74.8]
#  [-286.   211.8]]
# [[ 4.  -6. ]
#  [ 3.4 16. ]]

# %% [markdown]
# ## <font color='green'>3. Find the solution of the following set of linear algebraic equations:$$5x+6y+10z=4$$ $$-3x+14z=10$$ $$-7y+21z=0$$</font>

# %%
A=np.array([[5,6,10],[-3,0,14],[0,-7,21]])
inv_A = np.linalg.inv(A)

B = np.array([4, 10, 0])
X = np.linalg.inv(A).dot(B)
print(X)
# Out:
# [-1.45454545  1.20779221  0.4025974 ]

# %% [markdown]
# ## <font color='green'>4. Find the solution of the following set of linear algebraic equations such that $\Vert Ax-b\Vert^2_2$is minimized:$$5x+6y+10z=4$$ $$-3x+14z=10$$ $$-7y+21z=0$$$$2x-y+45z=16$$</font>

# %%
A=np.array([[5,6,10],[-3,0,14],[0,-7,21],[2,-1,45]])
B=np.array([4,10,0,16])
print(np.linalg.lstsq(A, B, rcond=None))
# Out:
# (array([-1.46103896,  1.2393321 ,  0.43692022]), array([1.]), 3, array([52.64886072,  9.83706621,  4.1628828 ]))

# %% [markdown]
# ## <font color='green'>5. create following two arrays:
# (a) Array of ones with 10 elements
# (b) Array a[1] = 2; a[2] = 3 and a[3] to a[10] are zero</font>

# %%
b=np.ones(10)
a=np.zeros(10)
a[1],a[2]=2,3

print(b)
print(a)

# %% [markdown]
# ## <font color='green'>6. Create two arrays indicating marks of students in two subjects. Get average vector of them.</font>

# %%
import numpy as np
  
#  create a numpy 1d-arrays
sub1 = np.array([5,7])
sub2 = np.array([6, 8])
  
# find average of NumPy arrays
avg = (sub1 + sub2) / 2
  
print("Average vector :\n",
      avg)
# Out:
# Average vector :
#  [5.5 7.5]

# %% [markdown]
# ## <font color='green'>7. Plot the following linear functions:
#
# 1.   $y=2x+3 $ from $-10\le x\le 10$
# 2.   $y=x-15 $ from $-10\le x\le 10$
# <font>

# %%
import matplotlib.pyplot as plt

x=np.linspace(-10,10,21)
plt.xlim(-10, 10)
plt.xlabel('x')
plt.ylabel("y=2x+3")
plt.plot(x, 2*x+3)
plt.show()

# %%
x=np.linspace(-10,10,21)
plt.xlim(-10, 10)
plt.xlabel('x')
plt.ylabel("y=x-15")
plt.plot(x, x-15)
plt.show()

# %% [markdown]
# ## <font color='green'>8. Plot the following non-linear functions:
#
# 1.   $y=2x^2+3x+1 $ from $-10\le x\le 10$
# 2.   $y=x^3+1 $ from $-10\le x\le 10$
# <font>

# %%
x=np.linspace(-10,10,21)
plt.xlim(-10, 10)
plt.xlabel('x')
plt.ylabel("y=2x^2+3x+1")
plt.plot(x, 2*pow(x,2)+3*x+1)
plt.show()

# %%
x=np.linspace(-10,10,21)
plt.xlim(-10, 10)
plt.xlabel('x')
plt.ylabel("y=x^3+1")
plt.plot(x, pow(x,3)+1)
plt.show()

# %% [markdown]
# ## <font color='green'>9. Write code to verify whether the given vectors are linearly independent or not.
# v1 = [6 0 3 1 4 2];
# v2 = [0 -1 2 7 0 5];
# v3 = [12 3 0 -19 8 -11].</font>

# %%
A=np.array([[6,0,12],[0,-1,3],[3,2,0],[1,7,-19],[4,0,8],[2,5,-11]])
print("Matrix Rank of A is",np.linalg.matrix_rank(A))
print("As we find out that  the given matrix's rank is not equal to 3 so the vectors are not linearly independent.")
# Out:
# Matrix Rank of A is 2
# As we find out that  the given matrix's rank is not equal to 3 so the vectors are not linearly independent.

# %% [markdown]
# ## <font color='green'>10. For real symmetric matrix.
# 1.   Find the Eigen values and eigen vectors
# 2.   Verify properties of Eigen values and Eigen vector.</font>
#
# As example, $A=\begin{bmatrix}1 & 2 & 3 \\2 & 5 & 6\\3 & 6 & 7
# \end{bmatrix}$

# %%
A=np.array([[1,2,3],[2,5,6],[3,6,7]])
np.linalg.eigh(A)
# Out:
# (array([-0.4667216 ,  0.32610415, 13.14061745]),
#  array([[ 0.66831303,  0.68784863, -0.28323481],
#         [ 0.42532424, -0.66571204, -0.61312867],
#         [-0.61029254,  0.28929525, -0.73746272]]))

# %% [markdown]
# ## <font color='green'>11. Write code for the following:
#
#
# 1.   Create a column vector with 10 values of temperature in degree centigrade $C^\circ$
# 2.   Convert each of the temperature values in degree Fahrenheit using the formula $$F^\circ=\frac{9}{2}C^\circ+32$$
# 1.   Make the final matrix with temperature values in $C^\circ$ as the first column and in F as the second column.
# <font>

# %%
def ctof(c):
  #write code here to convert c to f
  f = (9/5)*c + 32
  return f

# %%
celcius=np.array(np.random.randint(30,size=10))
print(celcius)
fahrenheit=np.array(ctof(celcius))
print(fahrenheit)
# Out:
# [25 23 24 17  7 25 19  9  4 23]
# [77.  73.4 75.2 62.6 44.6 77.  66.2 48.2 39.2 73.4]

# %% [markdown]
# ## <font color='green'>12. Determine the probability of 3 heads in 4 tosses of a coin with probability of head being $p=0.75$. Use a relative frequency interpretation of probability to yield the result.

# %%
print(pow(0.75,3)*pow(0.25,1)*4)
print("Relative frequency  =",3/4,"which is equal to probability of heads")
# Out:
# 0.421875
# Relative frequency  = 0.75 which is equal to probability of heads

# %% [markdown]
# ## <font color='green'>13. Write a program that will add all the numbers corresponding to the even indices of an array. Use that program to find the sum of all even integers from 1 to 1000.<font>

# %%
def addeven(u):
  sum=0
  for i in range(len(u)//2):
  #write code here
    sum+=u[2*i+1]
  return sum
  a= np.linspace(1,1000,1000)
addeven(a)
# Out:
# 250500.0

# %% [markdown]
# :## <font color='green'>14. Write a program to generate random number.<font>

# %%
from typing import Generator

def lcg(modulus: int, a: int, b: int, seed: int) -> Generator[int, None, None]:
    """Linear congruential generator."""
    while True:
        seed = (a * seed + b) % modulus
        yield seed

print(lcg(10,1,5,5))
print(np.random.randint(1,100000))
# Out:
# <generator object lcg at 0x7f565b07c450>
# 68544

# %% [markdown]
# <a href="https://colab.research.google.com/github/urmila-24/ML-Assignments/blob/main/201951164_URMILA_RATHORE_LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> IIIT Vadodara </center>
# ## <center> Winter 2021-22 </center>
# ## <center> CS 612/652, CS/IT 308 Machine Learning </center>
# ## <center> Lab#3 Principal component analysis (PCA) and Data generating process </center>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
from numpy import linalg as la
import matplotlib.image as mpimg
import glob
from numpy import linalg as LA
import scipy.io as sio 
from mpl_toolkits import mplot3d

# %% [markdown]
# ## <font color='red'> 1. Implement PCA for 2D Data.
#
# In this experiment consider 200 samples and obtain the matrix $X$ in $X = C \times D$, where $C=\begin{bmatrix}
# 1 & 2 \\
# 1 & 1 \end{bmatrix}$ and $D$ is the randomly generated matix using samples. <font>
#
#
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
# 2D Data for example
# Find X
C = np.array([[1, 2], [1, 1]])
D = np.random.rand(2, 200)
X = np.matmul(C, D)

# %%
# code to scatter plot X
plt.scatter(x = X[0, : ], y = X[1, : ])

# %% [markdown]
# ### Implement PCA
# Hint: refer class note

# %%
# Write code to impement PCA
C_X = np.cov(X)
E, P = np.linalg.eig(C_X)
idx = E.argsort()[::-1]   
E = E[idx]
P= P[:,idx]

print('eigen values=',E)
print('eigen vectors=\n',P)
# Out:
# eigen values= [0.52778827 0.01301438]
# eigen vectors=
#  [[ 0.8513584  -0.52458448]
#  [ 0.52458448  0.8513584 ]]

# %%
# Transform data to new coordinates
P = P.T
Y = np.matmul(P, X)

# scatter plot Y
plt.scatter(x = Y[0, : ], y = Y[1, : ])

# %%
#Approximate each 2-point data vector using one values
# Hint: Y[-1,:]=0
Y[-1, :] = 0


# scatter plot Y
plt.scatter(x = Y[0, : ], y = Y[1, :])

# %%
#Transform back to original coordinates
PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]

X_approx = PP * YY




# scatter plt X_approx
plt.scatter(x = X_approx[0, : ], y = X_approx[1, :])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-09ae905d64fc> in <module>()
#       4 Y = Y[:-1,:]
#       5
# ----> 6 X_approx = PP * YY
#       7
#       8
#
# NameError: name 'YY' is not defined

# %% [markdown]
# ## <font color='red'> 2. Implement PCA for 3D Data.
# In this experiment consider 200 samples and obtain the matrix $X$ in $X = C \times D$, where $$C=\begin{bmatrix}
# 1&2&-1\\
# 2&2&1\\
# -2&0&2\\
# \end{bmatrix}$$ and $D$ is the randomly generated matix using samples. <font>
#
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
# Write 3D Data and find X
C = np.array([[1, 2, -1], [2, 2, 1], [-2, 0, 2]])
D = np.random.rand(3, 200)
X = np.matmul(C, D)

X
# Out:
# array([[ 1.24942505,  0.78215805,  1.36251865,  1.12529823,  1.65691554,
#          0.63950693,  0.17156685,  1.67074736,  0.26633499,  0.14589883,
#          2.15272664,  0.13886619, -0.12038505,  1.8700497 ,  1.25331635,
#          0.81676991,  1.55971032,  0.72251727,  0.6133554 ,  1.88635898,
#          1.07300138,  1.66579145,  1.34220258,  0.846357  ,  0.29282243,
#          0.82734864,  0.07480958,  1.8716437 ,  1.24735373,  0.04297954,
#          1.03880719,  0.94114019,  0.64496359,  1.74370539,  0.39707281,
#          0.35988732,  1.88691229,  0.75210892,  0.78764988,  1.28327175,
#          1.2639967 ,  1.49230175,  1.07481836,  2.10409762,  0.85587191,
#          1.77564888,  0.22093212,  1.0479303 ,  1.30401857, -0.17872125,
#          0.88531616,  0.65919665,  0.31078074,  0.78684639,  1.16743805,
#          0.81740265,  0.13741176,  1.38770967, -0.15694559,  0.5091997 ,
#          0.31926334,  1.70556054,  2.02204455,  1.64035794, -0.56243613,
#          1.36430546,  2.16915114,  0.06508529,  1.45614865,  1.03493193,
#          0.58308259,  1.65565179,  1.60869998,  0.67568428,  1.26112433,
#          1.99143426,  1.1007598 ,  0.15340022,  1.49276912,  1.1528884 ,
#          0.40299129,  0.92436206,  1.45920921,  2.37988747,  1.24494198,
#          1.21049089,  0.65921222,  0.74747714,  2.01461699,  1.55496057,
#          1.90881855,  1.54277264,  1.30209285,  1.11735783,  0.82045379,
#          0.52672361, -0.26738776,  1.35076643,  0.61395276,  0.36681856,
#          0.28987055, -0.37098239,  2.0572431 ,  0.13417083,  1.5448301 ,
#          0.43967211,  2.29704122,  0.52983291,  0.52006641,  1.3056202 ,
#         -0.21388622,  1.02006673,  0.98667962,  0.30743966,  1.66830639,
#         -0.39785225,  0.62217136, -0.70691959,  1.40017102,  0.92880307,
#          0.81377122, -0.44787619,  1.0800736 ,  0.34407428,  1.74833456,
#          1.62489997,  1.71694041, -0.00489526,  1.78167758,  2.21960108,
#          1.28840147,  1.99286484,  0.65919779,  0.92091639,  0.50494319,
#          1.95039387,  1.52927121,  0.19732808,  0.40094361, -0.00558409,
#          1.22694609,  0.96270889,  1.39809521,  1.12407902,  1.82716871,
#          1.07819316, -0.15905513,  2.29787819,  0.58675441,  1.13586609,
#          1.73982394,  0.81251295,  0.19376265,  0.17926154,  2.16444322,
#          1.41880875,  0.31151815,  1.57896593,  0.60145009,  0.25314039,
#          1.71872025,  0.1360554 ,  1.22136771,  0.94470749,  1.89999221,
#          1.02217787,  0.66735185,  1.88653088,  0.79073575,  0.27491639,
#          0.95323477,  1.69197256,  0.57100668,  0.68220389,  0.20899824,
#          1.66972773,  2.14979763,  1.16347953,  1.82654929,  0.91526602,
#          1.25095664,  2.36716326,  0.36932285,  0.97267462,  1.90562717,
#          2.14454115,  0.01794575,  0.02644367,  1.7497051 ,  1.4006019 ,
#          1.54787133,  1.43617761,  1.29684631,  0.75870962,  0.53122144,
#          1.68381401,  1.90738927,  1.58944613,  1.7183165 ,  1.08030095],
#        [ 2.78228931,  3.57686311,  2.73336261,  2.62827812,  3.0360059 ,
#          2.73951065,  2.27294853,  2.64216025,  2.69788429,  0.84635482,
#          4.39114001,  2.53654824,  1.09437006,  4.21692605,  2.1742624 ,
#          2.78516216,  4.2806265 ,  2.74688631,  1.99433625,  3.30622014,
#          2.62795402,  2.65328998,  3.71391738,  2.80783315,  2.79189586,
#          1.31507914,  2.61341902,  2.48219047,  2.77493982,  1.0119464 ,
#          3.25548574,  1.93844196,  3.14721483,  4.00597704,  2.3477042 ,
#          3.04890103,  2.865915  ,  2.61945517,  2.61886781,  2.35457359,
#          2.87428638,  2.56894921,  2.08255718,  3.14363984,  2.13840579,
#          2.72830028,  1.70005028,  2.37513142,  3.31210999,  1.88076296,
#          2.65091698,  2.16627287,  2.50479027,  2.17169386,  2.03237236,
#          1.3550477 ,  0.63126827,  2.78596765,  1.74333302,  1.84576035,
#          1.49430388,  4.01584702,  2.82141073,  2.92698512,  1.62408485,
#          2.83023951,  3.73852819,  1.6662995 ,  3.8530988 ,  2.43390737,
#          1.57049278,  2.30715043,  3.21574912,  1.32059843,  2.67581615,
#          4.47159395,  2.5116219 ,  1.23916293,  2.80126011,  3.67593984,
#          2.04325508,  2.22386746,  3.03924321,  3.50885722,  3.07415065,
#          3.30415882,  2.96870093,  1.99877576,  4.52705299,  3.95045536,
#          2.88973701,  3.59926658,  2.65699356,  3.57377505,  3.01982997,
#          1.55579343,  1.51644082,  3.04940727,  2.36998184,  2.68152396,
#          2.12550014,  1.6438502 ,  3.73913056,  1.9954726 ,  3.09304425,
#          2.05181696,  3.20671379,  2.24046911,  1.70583066,  3.63799634,
#          2.167059  ,  2.02109669,  2.11726069,  2.13713992,  3.62724346,
#          1.82161103,  3.33177289,  1.12543823,  2.70494514,  2.37876091,
#          2.05995298,  2.02989407,  3.55771472,  1.05290589,  2.76916623,
#          2.50828823,  4.62246313,  1.04036131,  4.09388028,  4.22598086,
#          3.85739431,  3.58521166,  3.26384583,  2.58756575,  1.86050995,
#          3.58778516,  2.8155646 ,  2.76328948,  2.70318791,  2.4397586 ,
#          3.61849882,  3.18385783,  2.52360529,  2.65108499,  2.7458943 ,
#          2.84553215,  1.11749738,  2.9234273 ,  1.03566232,  3.5311776 ,
#          2.52334512,  2.36382752,  2.87062043,  1.8611942 ,  3.1128978 ,
#          3.87343672,  1.97820847,  3.71158663,  2.060165  ,  2.94310852,
#          3.41427865,  1.5457158 ,  3.22604995,  3.0741801 ,  2.3881202 ,
#          2.61735446,  2.05693047,  3.41759927,  1.72759501,  2.06229337,
#          3.39533765,  2.07733242,  2.38895848,  3.07583338,  2.5757846 ,
#          2.30617941,  4.45802611,  3.38501669,  4.25453887,  2.20978472,
#          2.18054305,  3.67794168,  2.79410288,  2.38387665,  2.52230307,
#          3.46036415,  1.8867585 ,  1.86770143,  3.73127123,  1.49990252,
#          3.19436337,  2.78446396,  1.37936152,  2.31517232,  3.1779655 ,
#          2.71744934,  2.77473154,  2.94271336,  2.92980055,  2.91387347],
#        [-0.02023504,  0.25548456, -1.31155232,  0.61796136,  0.16942629,
#         -0.19937091,  0.05086921,  0.58961672,  0.34341395,  0.51763771,
#         -0.33661714,  0.69293488,  1.13329507, -0.27888458, -0.52788283,
#          0.457194  ,  0.2970062 ,  0.68712241,  0.07233183,  0.187526  ,
#          1.41512417,  0.16975086,  0.29043121,  1.52770622, -0.00746939,
#         -0.46843955,  0.11044298, -0.30278034,  1.39235726,  0.58295661,
#          1.36308182, -0.24354694,  0.2810026 ,  0.32249496,  1.8470771 ,
#          0.44434597, -1.47714726,  0.48507598, -0.44429521,  0.67637398,
#         -0.96725949,  0.13834049,  0.21170086, -0.57697973,  0.38632057,
#          0.16963222, -0.09067534,  0.83668253,  0.02279772,  1.06282433,
#         -0.41637569, -0.31725439,  0.35101459, -1.01425878, -0.59521291,
#         -0.73292238,  0.44062933,  0.94708294,  0.56570975, -0.12091248,
#          1.12572751,  0.34626983, -0.51530269, -0.92302343,  1.57981884,
#         -0.50435872, -0.35786936,  0.48566792,  0.66360344,  0.22441893,
#         -0.69296293, -0.085994  ,  0.67658725, -0.47077905,  0.59689277,
#         -0.32836581, -1.29494131,  0.24751151,  0.73916852,  0.66312423,
#          1.21929534, -1.39667295, -1.3772806 , -1.18441467,  1.40033915,
#          0.83905122, -0.26107541, -0.7874504 , -0.13384057,  0.51618844,
#         -0.72922447, -0.18263494,  0.82268669,  0.68773724, -0.78058933,
#         -0.08176622,  0.57944916,  0.28535482,  1.58949086,  1.02300319,
#         -0.30961131,  1.84970003, -0.76824472,  0.04582924, -0.6561825 ,
#          0.86319818, -0.80742512, -0.04919999,  0.77903626,  1.00720384,
#          1.1551935 ,  0.01197745,  0.97306053,  1.51824928, -0.13416664,
#          1.07316113,  0.3307285 ,  1.63138375,  0.04214636, -1.10454591,
#         -0.04796556,  0.98156793,  0.65819849,  0.66873613, -0.07865891,
#         -0.76593914,  0.11234345,  0.79483721,  0.11098664, -0.69519733,
#          0.17145129, -1.3818724 ,  0.25096984, -1.04542634,  0.48951457,
#         -0.20458815, -0.21829339, -0.35025158,  0.81570749,  0.30447833,
#          0.45679343,  0.11729144, -1.10666088, -0.51199   , -0.10123513,
#         -1.04154274,  1.03968058, -0.81510515, -0.86606968,  1.17374566,
#         -0.90059646, -0.45063927,  0.23021364, -0.04791404, -1.6599905 ,
#          0.09122515,  1.48547109, -0.13950457,  0.76305654, -0.18080909,
#          0.44758109,  0.6365825 ,  0.37866353, -0.57796698, -0.67822085,
#          1.0785201 ,  1.31185814, -0.83152444, -0.15955496,  1.69260136,
#          0.26136952, -0.01076375, -0.32658084,  0.4055741 ,  0.78236857,
#         -0.46445696, -0.61521563,  0.47413776, -0.50743957, -1.0821747 ,
#         -0.68902621, -1.20197524,  0.26261622, -0.3180216 ,  0.13373015,
#         -0.69098061,  1.23287738,  1.03709788, -0.80703005, -0.15681328,
#         -0.21481823, -0.82047381, -0.04848893, -0.07173518, -0.30343463,
#         -0.37916358, -0.3299674 , -0.16756488, -1.44886621,  1.28841121]])

# %%
# write code to scatter plot 3D
fig = plt.figure(figsize = (4, 4))
ax = plt.axes(projection ="3d")

ax.scatter3D(X[0, :], X[1, :], X[2, :], color = "red")

# %% [markdown]
# ### Implement PCA
# Hint: refer class note.

# %%
#Write code here
C_X = np.cov(X)
E, P = np.linalg.eig(C_X)
idx = E.argsort()[::-1]   
E = E[idx]
P= P[:,idx]

print('eigen values=',E)
print('eigen vectors=\n',P)
# Out:
# eigen values= [1.08794112 0.47861158 0.13162605]
# eigen vectors=
#  [[ 0.59571091  0.0070269   0.80316819]
#  [ 0.6457939   0.59037925 -0.4841514 ]
#  [-0.47757592  0.80709539  0.34715743]]

# %%
# Transform data to new coordinates
#P = P.T
#Y = P*X
P = P.T
Y = np.matmul(P, X)

fig = plt.figure(figsize = (4, 4))
ax = plt.axes(projection ="3d")
#Scatter plt Y
ax.scatter3D(Y[0, :], Y[1, :], Y[2, :], color = "green")

# %%
#Transform back to original coordinates
#PP = P.T
#PP = PP[:,:-1]
#YY = Y[:-1,:]
#X_approx = PP*YY
#Transform back to original coordinates
PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]
X_approx = np.matmul(PP, YY)

#Scatter plot X_approx
fig = plt.figure(figsize = (4, 4))
ax = plt.axes(projection ="3d")

ax.scatter3D(X_approx[0, :], X_approx[1, :], X_approx[2, :], color = "yellow")

# %%
#Approximate each 3-point data vector using two values
Y[2,:]=0



#Scatter plot Y
fig = plt.figure(figsize = (4, 4))
ax = plt.axes(projection ="3d")

ax.scatter3D(Y[0, :], Y[1, :], Y[2, :], color = "blue")

# %% [markdown]
# ## <font color='red'> 3. Implement PCA for image compression.<font>
#     Methodology: A set of face images is used to generate a basis matrix using PCA. Essentially this basis matrix would the input data which are correlated observations from the real world. By preserving different number of eigenvectors, different degrees of compression can be achieved.

# %% [markdown]
# You can use this link for face images:
#
# https://drive.google.com/file/d/1XMtBihZypbE-zlg_DuAW63IF4vX4cn3d/view?usp=sharing

# %%
a=glob.glob('*.pgm') # to read all images
X1 = mpimg.imread(a[0])
plt.imshow(X1)
plt.colorbar()
[m,n]=np.shape(X1)
X = X1.flatten()
X = np.zeros(shape=(np.size(a),m*n))
for i,j in zip(a,range(np.size(a))):
    X[j,:]=  mpimg.imread(i).flatten()

# %%
#plot Eigen values of covariance matrix
C_X = np.cov(X)
E, P = np.linalg.eig(C_X)
idx = E.argsort()[::-1]   
E = E[idx]
P= P[:,idx]



plt.figure()
plt.plot(E)

# %%
#write code for PCA and approximate each data vector using few significant eigen values 

P = P.T
Y = np.matmul(P, X)
Y[30,:]=0

PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]
Xr = np.matmul(PP, YY)

X1r = np.reshape(Xr[0,:],[m,n])
plt.imshow(X1r)
plt.colorbar()
# Out:
# mse= 768.7009781064393

# %% [markdown]
# ### <font color='red'> Homework: Implement PCA for remote sensing image.<font>
#     Methodology: A set of remotely sensed images (Cuprite hyperspectral data having 188 bands) is used to generate a basis matrix based on PCA, and this matrix would be used to uncorrelate the data which are correlated. By preserving different number of eigenvectors different degrees of compression can be achieved. Find the variance of the input and output in each case and note the observations.

# %% [markdown]
# You can use this link for Cuprite images:
#
# https://drive.google.com/file/d/1XMtBihZypbE-zlg_DuAW63IF4vX4cn3d/view?usp=sharing

# %%
X = sio.loadmat('cuprite.mat')
X= X['x']
X1 = np.reshape(X,[188,191,250])
plt.figure()
plt.imshow(X1[1,:,:].T)
plt.colorbar()

# %%
#plot Eigen values of covariance matrix
C_X = np.cov(X)
E, P = np.linalg.eig(C_X)
idx = E.argsort()[::-1]   
E = E[idx]
P= P[:,idx]


plt.figure()
plt.plot(E)

# %%
#write code for PCA and approximate each data vector using few significant eigen values 
P = P.T
Y = np.matmul(P, X)
Y[150,:]=0

PP = P.T
PP = PP[:,:-1]
YY = Y[:-1,:]
Xr = np.matmul(PP, YY)

X1 = np.reshape(Xr[0],[191,250])

plt.figure()
plt.imshow(X1.T)
plt.colorbar()

# %% [markdown]
# ## <font color='red'> 4. Data generating process:
# In this experiment take two zero mean, unit variance, uncorrelated Gaussian random variables. Obtain the transformation matrix $A$ in $Y = A \times X$ such that $Y$ has a specified covariance matrix. (Take any valid covariance matrix in this case)<font>
# Hint: $$Y=AX$$ $$C_Y=AC_XA^T$$ Digonalize $$C_Y=U\Sigma U^{-1}$$ So, $$U\Sigma^{\frac{1}{2}}\Sigma^{\frac{1}{2}} U^{-1}=AC_XA^T$$ If, $X$ is uncorrelated then $C_X$ must be identity.
# <br>
# Hint for Code: Use np.linalg.eig, np.diag, np.matmul, np.cov

# %%
#  For example use this Cy
Cy = np.array([[4 , 2],
               [2 , 4]])
print(Cy)
# Out:
# [[4 2]
#  [2 4]]

# %%
no_samples = 1000

#Write code here
no_samples = 1000
X = np.random.normal(0, 1, size=(2, 1000))
C_X = np.cov(X)
E, U = np.linalg.eig(Cy)

idx = E.argsort()[::-1]   
E = E[idx]
U= U[:,idx]

E = np.diag(E)


A = np.matmul(U, np.power(E, 0.5))
Y = np.matmul(A, X)

Cynew = np.cov(Y)


print("Cy_new=",Cynew)
# Out:
# Cy_new= [[3.60394072 1.75701702]
#  [1.75701702 3.94900157]]

# %% [markdown]
# ### <font color='red'> Homework: Consider providing more valid covariance matrices and generate correlated random data using the reverse PCA operation done in Problem-4. This is an instance of data generating process useful in machine learning algorithms.

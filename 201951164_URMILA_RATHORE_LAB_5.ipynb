# %% [markdown]
# <a href="https://colab.research.google.com/github/urmila-24/ML-Assignments/blob/main/201951164_URMILA_RATHORE_LAB_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> IIIT Vadodara </center>
# ## <center> Winter 2021-22 </center>
# ## <center> CS 612/652, CS/IT 308 Machine Learning </center>
# ## <center> Lab#5 Basic optimization techniques </center>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc
from scipy.io import wavfile
from numpy import linalg as la
import matplotlib.image as mpimg
import glob
from numpy import linalg as LA
import scipy.io as sio

# %% [markdown]
# **Problem 1)** Find minima of following functions using gradient descent method with learning rate 0.01 and 0.1 along with different number of iterations. Try choosing a large value of learning rate and test the convergence. Plot the functions, highlight corresponding minima, and show convergence/divergence on the plot.
#
# (a) $L_1(θ) = θ^2$
#
# (b) $L_2(θ) = θ_1^2 + θ_2^2$
#
# (c) $L_3(θ) = (θ - 1)^2$
#
# (d) $L_4(θ) = 2 (θ_1-1)^2 + 2(θ_2-1)^2$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import statistics as st
import sympy as sy

# you can assume theta=5000000
# p=theta+1
# e=0.000001
# aplha=0.1

# can use while loop for |p-theta|>e
theta0=10000
theta1=50000
p0 = theta0+1
p1 = theta1+1 
e=0.000001
alpha=0.1
def cost_func(theta0,theta1):
    cost0 = 2*(theta0)
    cost1 = 2*(theta1)
    return cost0,cost1
count = 0
a = []
while abs(theta0-p0)>e or abs(theta1-p1)>e:
    p0 = theta0
    p1 = theta1
    theta0 = theta0 - 0.1*(cost_func(theta0,theta1)[0])
    theta1 = theta1 - 0.1*(cost_func(theta0,theta1)[1])
    a.append(theta0*2+theta1*2)
    count += 1
print(theta0,theta1)
print(count)
# Out:
# 6.67495948725285e-07 3.3374797436264246e-06
# 105

# %% [markdown]
# Q1 (b)

# %%
#theta0=10000
#theta1=50000

#e=0.000001
#alpha=0.1

# can use while loop for |theta0-p0|>e or |theta1-p1|>e:
theta=5000000
p=theta+1
e=0.000001
alpha=0.1

def cost_fun(theta):
    cost = 2*theta
    return cost

count = 0
a = []

while abs(p-theta)>e:
    p = theta
    a.append(theta**2)
    theta = theta - .1*(cost_fun(theta))
    count += 1

print(theta)
print(count)
# Out:
# 3.847852167616652e-06
# 125

# %% [markdown]
# Q1 (c)

# %%
# theta0=50
# p=theta0+1
# e=0.000001
# alpha=0.1

# while for |theta0-p|>e:
theta=50
p=theta+1
e=0.000001
alpha=0.1

def cost_fun(theta):
    cost = 2*theta
    return cost

count = 0
a = []

while abs(theta-p)>e:
    p = theta
    a.append((theta-1)**2)
    theta = theta - 0.1*(cost_fun(theta))
    count += 1

print(theta)
print(count)
# Out:
# 3.3699933333938316e-06
# 74

# %% [markdown]
# Q1 (d)

# %%
#theta0=10000
#theta1=50000


#e=0.000001
#alpha=0.1

#while loop for |theta0-p0|>e or |theta1-p1|>e:
theta0=10000
theta1=50000
p0 = theta0+1
p1 = theta1+1 
e=0.000001
alpha=0.1
def cost_func(theta0,theta1):
    cost0 = 2*(theta0)
    cost1 = 2*(theta1)
    return cost0,cost1
count = 0
a = []
while abs(theta0-p0)>e or abs(theta1-p1)>e:
    p0 = theta0
    p1 = theta1
    theta0 = theta0 - 0.1*(cost_func(theta0,theta1)[0])
    theta1 = theta1 - 0.1*(cost_func(theta0,theta1)[1])
    a.append((2*theta0-1)*2+(2*theta1-1)*2)
    count += 1
print(theta0,theta1)
print(count)
# Out:
# 6.67495948725285e-07 3.3374797436264246e-06
# 105

# %% [markdown]
# **Problem 2)** Consider $A=\begin{bmatrix}
# 0.7 & 0.2\\
# 0.1 & 0.6
# \end{bmatrix}$ and the observation matrix $b=\begin{bmatrix}
# 0.5\\
# 0.6
# \end{bmatrix}$ in a system $Ax=b$. However, $b$ is not in column space of $A$, thus $Ax \neq b$ and we need to find $x$ in such a way that $Ax \approx b$. Using linear least square $x$ can be estimated by minimizing the mean squared error as,  $\min ||Ax-b||_2$.
#
# <br>
# This can be written as,
#
# $\underset{x}{\mathrm{argmin}}||Ax-b||_{2}^{2} = f(x)$
#
# We need to find $x$ in such a way that $f(x)$ will be minimum in $L_2$ norm.
#
# <br>
#
# You need to solve this least square problem using gradient descent algortithm on $f(x)$.
#
# <br>
# To apply this algorithm we need to find gradient of the function, i.e.,
# <br>
#               $\Delta_x f(x)= A^T(Ax-b) = A^TAx-A^Tb$
#
# <br>
#
# Optimisation for least-squares
# <br>
# $||A^TAx-A^Tb||_2>\delta$, $\delta$ is the small positive number indicating tolerance.
#
# <br>
#
# Now we will find new $x$ iteratively using step size $\alpha$ to find the best fit for $AX=b$ as:
#
# <br>
# $x^{[n+1]}=x^{[n]}-\alpha (A^TAx-A^Tb)$.
# <br>
#
# We need to choose $\alpha$, $\delta$ and $x^{[0]}$ to iterate until $x^{[n+1]} \rightarrow x^{[n]}$.

# %%
#Write your code here.
A = np.array([0.7,0.2,0.1,0.6]).reshape(2,2)
b = np.array([0.5,0.6]).reshape(2,1)
x = np.array([0.3,0.4]).reshape(2,1)
dell = 0.0000000001
alpha = 0.01
d = 100
count = 0
while d > dell:
    Norm = A.T@A@x - A.T@b
    d = np.linalg.norm(Norm)
    x = x - alpha*(Norm)
    count += 1
print(x)
print(count)
# Out:
# [[0.45 ]
#  [0.925]]
# 8390

# %% [markdown]
# **Problem 3)** Apply stochastic gradient algorithm on the given dataset and estimate $\theta_0$, $\theta_1$ and final cost value. Step by step hints have been given for the same.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.style.use(['ggplot'])

# %% [markdown]
# 1) Dataset:

# %%
X = 2 * np.random.rand(100,1)
y = 4 + 3 * X + np.random.randn(100,1)

# %% [markdown]
# 2) Visualize the data.

# %%
#Write code here
plt.scatter(X,y,c = "Green",s =10)
plt.show()

# %% [markdown]
# 3) We will write the line equation $y=m \space x+c$ in machine learning form as $J(\theta)=\theta_1 X + \theta_0$. Now choose one random sample $X_b$ (you can concatenate ones and $X$) and find $\theta_{best} = (X_b^T X_b)^{-1}X_b^Ty$.

# %%
#Write code here.
X_b = np.column_stack((np.ones(100),X))
theta_best = np.linalg.inv(X_b.T@X_b)@X_b.T@y
print(theta_best)
# Out:
# [[4.31281696]
#  [2.85714216]]

# %% [markdown]
# 4) For example choose $X_{new}=\begin{bmatrix}
# 0 \\
# 2
# \end{bmatrix}$. Obtain $X_{new_b}$ by concatinating ones and $X_{new}$. Finally find $y_{predict}=X_{new_b}\theta_{best}$.

# %%
#Write code here.
X_new = np.array([0,2]).reshape(2,1)
X_new_b = np.column_stack((np.ones(2),X_new))
y_pred = X_new_b@theta_best

print(y_pred)
# Out:
# [[ 4.31281696]
#  [10.02710127]]

# %% [markdown]
# 5) Visualize $X_{new}$ and $y_{predict}$.

# %%
#Write code here.
plt.plot(X_new,y_pred)
plt.scatter(X,y,c = "Green",s = 10)
plt.show()

# %% [markdown]
# 6) Define the cost function.

# %%
def  cal_cost(theta,X,y):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1/2*m) * np.sum(np.square(predictions-y))
    return cost

# %% [markdown]
# 7) Define the gradient descent function.

# %%
def gradient_descent(X,y,theta,learning_rate=0.01,iterations=100):
    m = len(y)
    cost_history = np.zeros(iterations)
    theta_history = np.zeros((iterations,2))
    for it in range(iterations):
        prediction = np.dot(X,theta)
        theta = theta -(1/m)*learning_rate*( X.T.dot((prediction - y)))
        theta_history[it,:] =theta.T
        cost_history[it]  = cal_cost(theta,X,y)
    return theta, cost_history, theta_history

# %% [markdown]
# 8) Using learning rate $0.01$ and $1000$ iterations find $\theta_0$, $\theta_1$ and final cost.

# %%
lr =0.01
n_iter = 1000
theta = np.random.randn(2,1)
X_b = np.c_[np.ones((len(X),1)),X]
theta,cost_history,theta_history = gradient_descent(X_b,y,theta,lr,n_iter)
print('Theta0:          {:0.3f},\nTheta1:          {:0.3f}'.format(theta[0][0],theta[1][0]))
print('Final cost/MSE:  {:0.3f}'.format(cost_history[-1]))
# Out:
# Theta0:          3.964,
# Theta1:          3.138
# Final cost/MSE:  4721.960

# %% [markdown]
# 9) Plot $J(\theta)$ and iterations.

# %%
#Write code here.
plt.figure(figsize = (10,10))
for i in range(n_iter):
    plt.scatter(i,cost_history[i],c = "green",s = 5)
plt.xlabel("Iterations")
plt.ylabel("J(theta)")
plt.show()

# %% [markdown]
# 10) You can also observe the changes in cost function.

# %%
#Write code here.
plt.figure(figsize = (11,11))
for i in range(1,201):
    plt.scatter(i,cost_history[i]-cost_history[i+1],c = "red",s = 5)
plt.show()

# %% [markdown]
# **Problem 4)** Find minimum of the function $L(θ)$ = using stochastic gradient descent method (take the data from the excel sheet given). Choose different learning rates and number of iterations.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import statistics as st
import sympy as sy
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-02e26f00-ac25-4721-99a6-c49ad9437d31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02e26f00-ac25-4721-99a6-c49ad9437d31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
import random

#Read the excel sheet given

#x = np.array(df['x'])
#y = np.array(df['y'])


#noralize x

theta1 = 1000
theta2 = 500


eps = 1e-6
alpha = 0.01
cnt = 0

# use while loop for |prev1-theta1| >= eps or |prev2-theta2| >= eps:
    
    




    
    
print(theta1,theta2)
print(cnt)
